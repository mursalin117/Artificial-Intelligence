# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Normal data distribution and histogram drawing
# 100000 random values with mean 5.0 and standard deviation 1.0
x = np.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()
